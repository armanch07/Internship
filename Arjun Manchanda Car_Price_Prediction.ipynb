# %% [markdown]
# # PROBLEM STATEMENT
#
# With the covid 19 impact in the market, we have seen lot of changes in the car market. Now some
# cars are in demand hence making them costly and some are not in demand hence cheaper. One
# of our clients works with small traders, who sell used cars. With the change in market due to covid
# 19 impact, our client is facing problems with their previous car price valuation machine learning
# models. So, they are looking for new machine learning models from new data. We have to make
# car price valuation model. This project contains two phaseData Collection Phase
# You hav to scrape at least 5000 used cars data. You can scrape more data as well, it’s up to you.
# more the data better the model
# In this section You need to scrape the data of used cars from websites (Olx, cardekho, Cars24
# etc.) You need web scraping for this. You have to fetch data for different locations. The number of
# columns for data doesn’t have limit, it’s up to you and your creativity. Generally, these columns are
# Brand, model, variant, manufacturing year, driven kilometers, fuel, number of owners, location and
# at last target variable Price of the car. This data is to give you a hint about important variables in
# used car model. You can make changes to it, you can add or you can remove some columns, it
# completely depends on the website from which you are fetching the data.
# Try to include all types of cars in your data for example- SUV, Sedans, Coupe, minivan,
# Hatchback.

# %%
#### First scrap the data from OLX,CARS24,CARDEKHO ETC
#### SO IMPORT BASIC LIBRARIES TO SCRAP DATA

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import time

# %%
### connect to the web driver
driver=webdriver.Chrome(r'D:\flip Robo\chromedriver.exe')

# %%
##### Open the URL for new delhi location
URL = 'https://www.cars24.com/buy-used-cars-new-delhi/?itm_source=Cars24Website&itm_medium=sticky_header'
driver.get(URL)
time.sleep(2)

# %%
#columns are 
#Brand, model, variant, manufacturing year, driven kilometers, fuel, number of owners, location and 
#at last target variable Price of the car

# %%
### all car links
links = driver.find_elements_by_xpath('/html/body/div[1]/div[2]/div/div[3]/div[1]/div/div/a')
url = []
# here m rotating the loop to scrap 
for i in links:
    url.append(i.get_attribute('href'))

# %%
url
# Out:
# ['https://www.cars24.com/buy-used-Maruti-S-PRESSO-2020-cars-New-Delhi-1108486124/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-2013-cars-New-Delhi-1052417645/',
#  'https://www.cars24.com/buy-used-Maruti-S-PRESSO-2020-cars-New-Delhi-1008498041/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2015-cars-New-Delhi-1003246126/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-K10-2017-cars-New-Delhi-1000899005/',
#  'https://www.cars24.com/buy-used-Honda-Amaze-2015-cars-Noida-1058981048/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2017-cars-Noida-1006047343/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2015-cars-New-Delhi-1007649408/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2014-cars-Faridabad-1057739946/',
#  'https://www.cars24.com/buy-used-Renault-Kwid-2018-cars-New-Delhi-1009689402/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2013-cars-New-Delhi-1015168847/',
# ...

# %%
Brand = []
Model = []
Variant = []
Manufacturing = []
Kilometers = []
Fuel = []
Location = []
Price = []
Owner = []
for i in url:
    driver.get(i)
    try:
        
        manufacturing = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/h2').text[0:4]
        brand = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/h2').text[5:11]
        model = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/h2').text[12:16]
        variant = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/h2').text[17:23]
        kilometer =driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[3]/div/div/div/div/ul/li[3]/strong').text
        fuel = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/ul/li[3]').text
        location = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[4]/div/div/div/div[1]/p/span').text
        price = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[3]/strong').text[10:18]
        owner = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/ul/li[5]').text
        Brand.append(brand)
        Model.append(model)
        Variant.append(variant)
        Kilometers.append(kilometer)
        Fuel.append(fuel)
        Location.append(location)
        Manufacturing.append(manufacturing)
        Owner.append(owner)
        Price.append(price)
    except NoSuchElementException:
        try:
            manufacturing = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/h2').text[0:4]
            brand = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/h2').text[5:11]
            model = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/h2').text[12:16]
            variant = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/h2').text[17:23]
            kilometer =driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/ul/li[1]').text
            fuel = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/ul/li[3]').text
            location = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[4]/div/div/div/div[1]/p/span').text
            price = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[2]/strong').text[10:18]
            owner = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/ul/li[5]').text
            Brand.append(brand)
            Model.append(model)
            Variant.append(variant)
            Kilometers.append(kilometer)
            Fuel.append(fuel)
            Location.append(location)
            Manufacturing.append(manufacturing)
            Owner.append(owner)
            Price.append(price)
        except NoSuchElementException:
            Brand.append('--')
            Model.append('--')
            Variant.append('--')
            Kilometers.append('--')
            Fuel.append('--')
            Location.append('--')
            Manufacturing.append('--')
            Owner.append('--')
            Price.append('--')

# %%
csv1 = pd.DataFrame({
    'Manufacturing':Manufacturing,
    'Brand':Brand,
    'Model':Model,
    'Variant':Variant,
    'Kilometers':Kilometers,
    'Fuel':Fuel,
    'Location':Location,
    'Owner':Owner,
    'Price':Price
})

# %%
csv1
# Out:
#     Manufacturing   Brand Model Variant Kilometers    Fuel Location  \
# 0            2020  Maruti  S PR  SSO VX   3,176 km  Petrol    DELHI
# 1            2013  Maruti  Swif   ZDI M  24,022 km  Diesel    DELHI
# 2            2020  Maruti  S PR  SSO VX   7,556 km  Petrol    DELHI
# 3            2015  Maruti  Alto  800 LX   9,217 km  Petrol    DELHI
# 4            2017  Maruti  Alto  K10 VX  11,691 km  Petrol    DELHI
# ..            ...     ...   ...     ...        ...     ...      ...
# 155          2020  Maruti  Alto  LXI MA   9,641 km  Petrol    DELHI
# 156          2010  Maruti  Ritz  ZXI MA  41,832 km  Petrol    DELHI
# 157          2014  Honda   maze  1.5 EM  34,868 km  Diesel    DELHI
# 158          2020  Maruti  Alto  LXI MA  11,520 km  Petrol    DELHI
# 159          2020  Maruti  New   agon-R   6,636 km  Petrol    DELHI
#
#          Owner     Price
# 0    1st Owner  4,02,199
# 1    1st Owner  3,96,599
# 2    1st Owner  4,01,899
# 3    1st Owner  2,58,599
# ...

# %%
##### Open the URL for new mumbai location
URL2 = 'https://www.cars24.com/buy-used-car?sort=P&storeCityId=2378&pinId=400001'
driver.get(URL2)
time.sleep(2)

# %%
### all car links
link = driver.find_elements_by_xpath('/html/body/div[1]/div[2]/div/div[3]/div[1]/div/div/a')
urls = []
# here m rotating the loop to scrap 
for i in link:
    urls.append(i.get_attribute('href'))

# %%
urls
# Out:
# ['https://www.cars24.com/buy-used-Maruti-Swift-Dzire-2014-cars-Mumbai-1032179107/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-2013-cars-Mumbai-1035102845/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-2012-cars-Mumbai-1031273641/',
#  'https://www.cars24.com/buy-used-Maruti-Wagon-R-1.0-2014-cars-Mumbai-1033497741/',
#  'https://www.cars24.com/buy-used-Maruti-Wagon-R-1.0-2014-cars-Mumbai-1034677340/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-Dzire-2015-cars-Mumbai-1031729007/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2013-cars-Mumbai-1032819346/',
#  'https://www.cars24.com/buy-used-Hyundai-Grand-i10-2014-cars-Mumbai-1034370044/',
#  'https://www.cars24.com/buy-used-Renault-Kwid-2018-cars-Mumbai-1034300440/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-Dzire-2014-cars-Mumbai-1030834622/',
#  'https://www.cars24.com/buy-used-Renault-Kwid-2017-cars-Mumbai-1063121349/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-2018-cars-Mumbai-1065461946/',
# ...

# %%
Brand = []
Model = []
Variant = []
Manufacturing = []
Kilometers = []
Fuel = []
Location = []
Price = []
Owner = []
for i in url:
    driver.get(i)
    try:
        
        manufacturing = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/h2').text[0:4]
        brand = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/h2').text[5:11]
        model = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/h2').text[12:16]
        variant = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/h2').text[17:23]
        kilometer =driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[3]/div/div/div/div/ul/li[3]/strong').text
        fuel = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/ul/li[3]').text
        location = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[4]/div/div/div/div[1]/p/span').text
        price = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[3]/strong').text[10:18]
        owner = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/ul/li[5]').text
        Brand.append(brand)
        Model.append(model)
        Variant.append(variant)
        Kilometers.append(kilometer)
        Fuel.append(fuel)
        Location.append(location)
        Manufacturing.append(manufacturing)
        Owner.append(owner)
        Price.append(price)
    except NoSuchElementException:
        try:
            manufacturing = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/h2').text[0:4]
            brand = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/h2').text[5:11]
            model = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/h2').text[12:16]
            variant = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/h2').text[17:23]
            kilometer =driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/ul/li[1]').text
            fuel = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/ul/li[3]').text
            location = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[4]/div/div/div/div[1]/p/span').text
            price = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[2]/strong').text[10:18]
            owner = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/ul/li[5]').text
            Brand.append(brand)
            Model.append(model)
            Variant.append(variant)
            Kilometers.append(kilometer)
            Fuel.append(fuel)
            Location.append(location)
            Manufacturing.append(manufacturing)
            Owner.append(owner)
            Price.append(price)
        except NoSuchElementException:
            Brand.append('--')
            Model.append('--')
            Variant.append('--')
            Kilometers.append('--')
            Fuel.append('--')
            Location.append('--')
            Manufacturing.append('--')
            Owner.append('--')
            Price.append('--')

# %%
csv2 = pd.DataFrame({
    'Manufacturing':Manufacturing,
    'Brand':Brand,
    'Model':Model,
    'Variant':Variant,
    'Kilometers':Kilometers,
    'Fuel':Fuel,
    'Location':Location,
    'Owner':Owner,
    'Price':Price
})

# %%
csv2
# Out:
#     Manufacturing   Brand Model Variant Kilometers    Fuel Location  \
# 0            2020  Maruti  S PR  SSO VX   3,176 km  Petrol   MUMBAI
# 1            2013  Maruti  Swif   ZDI M  24,022 km  Diesel   MUMBAI
# 2            2020  Maruti  S PR  SSO VX   7,556 km  Petrol   MUMBAI
# 3            2015  Maruti  Alto  800 LX   9,217 km  Petrol   MUMBAI
# 4            2017  Maruti  Alto  K10 VX  11,691 km  Petrol   MUMBAI
# ..            ...     ...   ...     ...        ...     ...      ...
# 155          2020  Maruti  Alto  LXI MA   9,641 km  Petrol   MUMBAI
# 156          2010  Maruti  Ritz  ZXI MA  41,832 km  Petrol   MUMBAI
# 157          2014  Honda   maze  1.5 EM  34,868 km  Diesel   MUMBAI
# 158          2020  Maruti  Alto  LXI MA  11,520 km  Petrol   MUMBAI
# 159          2020  Maruti  New   agon-R   6,636 km  Petrol   MUMBAI
#
#          Owner     Price
# 0    1st Owner  4,02,199
# 1    1st Owner  3,96,599
# 2    1st Owner  4,01,899
# 3    1st Owner  2,58,599
# ...

# %%
##### Open the URL for new bengaluru location
URL3 = 'https://www.cars24.com/buy-used-cars-bengaluru/?itm_source=Cars24Website&itm_medium=sticky_header'
driver.get(URL3)
time.sleep(2)

# %%
### all car links
link_url = driver.find_elements_by_xpath('/html/body/div[1]/div[2]/div/div[3]/div[1]/div/div/a')
page = []
# here m rotating the loop to scrap 
for i in link_url:
    page.append(i.get_attribute('href'))

# %%
page
# Out:
# ['https://www.cars24.com/buy-used-Hyundai-Santro-Xing-2011-cars-Bengaluru-1026426024/',
#  'https://www.cars24.com/buy-used-Renault-Pulse-2016-cars-Bengaluru-1026130321/',
#  'https://www.cars24.com/buy-used-Maruti-Ritz-2011-cars-Bengaluru-1029793323/',
#  'https://www.cars24.com/buy-used-Tata-Tiago-2017-cars-Bengaluru-1029797208/',
#  'https://www.cars24.com/buy-used-Hyundai-Grand-i10-2016-cars-Bengaluru-1026237846/',
#  'https://www.cars24.com/buy-used-Volkswagen-Polo-2013-cars-Bengaluru-1028688509/',
#  'https://www.cars24.com/buy-used-Hyundai-Eon-2016-cars-Bengaluru-1026615004/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2013-cars-Bengaluru-1028735001/',
#  'https://www.cars24.com/buy-used-Hyundai-Santro-Xing-2011-cars-Bengaluru-1024256821/',
#  'https://www.cars24.com/buy-used-Maruti-OMNI-E-2017-cars-Bengaluru-1028551641/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2017-cars-Bengaluru-1028583843/',
# ...

# %%
Brand = []
Model = []
Variant = []
Manufacturing = []
Kilometers = []
Fuel = []
Location = []
Price = []
Owner = []
for i in page:
    driver.get(i)
    try:
        
        manufacturing = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/h2').text[0:4]
        brand = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/h2').text[5:11]
        model = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/h2').text[12:16]
        variant = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/h2').text[17:23]
        kilometer =driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[3]/div/div/div/div/ul/li[3]/strong').text
        fuel = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/ul/li[3]').text
        location = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[4]/div/div/div/div[1]/p/span').text
        price = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[3]/strong').text[10:18]
        owner = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/ul/li[5]').text
        Brand.append(brand)
        Model.append(model)
        Variant.append(variant)
        Kilometers.append(kilometer)
        Fuel.append(fuel)
        Location.append(location)
        Manufacturing.append(manufacturing)
        Owner.append(owner)
        Price.append(price)
    except NoSuchElementException:
        try:
            manufacturing = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/h2').text[0:4]
            brand = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/h2').text[5:11]
            model = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/h2').text[12:16]
            variant = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/h2').text[17:23]
            kilometer =driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/ul/li[1]').text
            fuel = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/ul/li[3]').text
            location = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[4]/div/div/div/div[1]/p/span').text
            price = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[2]/strong').text[10:18]
            owner = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/ul/li[5]').text
            Brand.append(brand)
            Model.append(model)
            Variant.append(variant)
            Kilometers.append(kilometer)
            Fuel.append(fuel)
            Location.append(location)
            Manufacturing.append(manufacturing)
            Owner.append(owner)
            Price.append(price)
        except NoSuchElementException:
            Brand.append('--')
            Model.append('--')
            Variant.append('--')
            Kilometers.append('--')
            Fuel.append('--')
            Location.append('--')
            Manufacturing.append('--')
            Owner.append('--')
            Price.append('--')

# %%
csv3 = pd.DataFrame({
    'Manufacturing':Manufacturing,
    'Brand':Brand,
    'Model':Model,
    'Variant':Variant,
    'Kilometers':Kilometers,
    'Fuel':Fuel,
    'Location':Location,
    'Owner':Owner,
    'Price':Price
})

# %%
csv3
# Out:
#    Manufacturing   Brand Model Variant Kilometers    Fuel   Location  \
# 0           2011  Hyunda   San  ro Xin  16,261 km  Petrol  BENGALURU
# 1           2016  Renaul   Pul  e RX L  30,523 km  Petrol  BENGALURU
# 2           2011  Maruti  Ritz  LXI MA  27,561 km  Petrol  BENGALURU
# 3           2017  Tata T  ago   T 1.2   18,871 km  Petrol  BENGALURU
# 4           2016  Hyunda   Gra  d i10   25,000 km  Petrol  BENGALURU
# ..           ...     ...   ...     ...        ...     ...        ...
# 95          2015  Maruti  Wago   R 1.0  29,109 km  Petrol  BENGALURU
# 96          2011  Hyunda   i20  MAGNA   59,172 km  Petrol  BENGALURU
# 97          2012  Ford F  go 1  2 TITA  25,954 km  Petrol  BENGALURU
# 98          2012  Maruti  Alto  K10 VX  36,453 km  Petrol  BENGALURU
# 99          2010  Maruti  Alto  K10 VX  56,095 km  Petrol  BENGALURU
#
#         Owner     Price
# 0   1st Owner  3,19,599
# 1   1st Owner  3,58,599
# 2   2nd Owner  3,42,099
# 3   2nd Owner  4,74,499
# ...

# %%
##### Open the URL for new kolkata location
URL4 = 'https://www.cars24.com/buy-used-car?sort=P&storeCityId=777&pinId=700001'
driver.get(URL4)
time.sleep(2)

# %%
### all car links
link_k = driver.find_elements_by_xpath('/html/body/div[1]/div[2]/div/div[3]/div[1]/div/div/a')
page1 = []
# here m rotating the loop to scrap 
for i in link_k:
    page1.append(i.get_attribute('href'))

# %%
page1
# Out:
# ['https://www.cars24.com/buy-used-Maruti-Alto-K10-2012-cars-Kolkata-1194115248/',
#  'https://www.cars24.com/buy-used-Hyundai-Grand-i10-2016-cars-Kolkata-1193426248/',
#  'https://www.cars24.com/buy-used-Hyundai-Elite-i20-2015-cars-Kolkata-1190813749/',
#  'https://www.cars24.com/buy-used-Maruti-Wagon-R-1.0-2015-cars-Kolkata-1191829844/',
#  'https://www.cars24.com/buy-used-Renault-Kwid-2017-cars-Kolkata-1191177749/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-Dzire-2016-cars-Kolkata-1194840743/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2018-cars-Kolkata-1195135141/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2013-cars-Kolkata-1198496847/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-2018-cars-Kolkata-1192708242/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2014-cars-Kolkata-1194593245/',
#  'https://www.cars24.com/buy-used-Hyundai-Grand-i10-2018-cars-Kolkata-1192857044/',
# ...

# %%
Brand = []
Model = []
Variant = []
Manufacturing = []
Kilometers = []
Fuel = []
Location = []
Price = []
Owner = []
for i in page1:
    driver.get(i)
    try:
        
        manufacturing = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/h2').text[0:4]
        brand = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/h2').text[5:11]
        model = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/h2').text[12:16]
        variant = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/h2').text[17:23]
        kilometer =driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[3]/div/div/div/div/ul/li[3]/strong').text
        fuel = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/ul/li[3]').text
        location = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[4]/div/div/div/div[1]/p/span').text
        price = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[3]/strong').text[10:18]
        owner = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/ul/li[5]').text
        Brand.append(brand)
        Model.append(model)
        Variant.append(variant)
        Kilometers.append(kilometer)
        Fuel.append(fuel)
        Location.append(location)
        Manufacturing.append(manufacturing)
        Owner.append(owner)
        Price.append(price)
    except NoSuchElementException:
        try:
            manufacturing = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/h2').text[0:4]
            brand = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/h2').text[5:11]
            model = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/h2').text[12:16]
            variant = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/h2').text[17:23]
            kilometer =driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/ul/li[1]').text
            fuel = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/ul/li[3]').text
            location = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[4]/div/div/div/div[1]/p/span').text
            price = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[2]/strong').text[10:18]
            owner = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/ul/li[5]').text
            Brand.append(brand)
            Model.append(model)
            Variant.append(variant)
            Kilometers.append(kilometer)
            Fuel.append(fuel)
            Location.append(location)
            Manufacturing.append(manufacturing)
            Owner.append(owner)
            Price.append(price)
        except NoSuchElementException:
            Brand.append('--')
            Model.append('--')
            Variant.append('--')
            Kilometers.append('--')
            Fuel.append('--')
            Location.append('--')
            Manufacturing.append('--')
            Owner.append('--')
            Price.append('--')

# %%
csv4 = pd.DataFrame({
    'Manufacturing':Manufacturing,
    'Brand':Brand,
    'Model':Model,
    'Variant':Variant,
    'Kilometers':Kilometers,
    'Fuel':Fuel,
    'Location':Location,
    'Owner':Owner,
    'Price':Price
})

# %%
csv4
# Out:
#     Manufacturing   Brand Model Variant   Kilometers    Fuel Location  \
# 0            2012  Maruti  Alto  K10 LX     1,448 km  Petrol  KOLKATA
# 1            2016  Hyunda   Gra  d i10     12,776 km  Petrol  KOLKATA
# 2            2015  Hyunda   Eli  e i20     28,228 km  Petrol  KOLKATA
# 3            2015  Maruti  Wago   R 1.0    17,668 km  Petrol  KOLKATA
# 4            2017  Renaul   Kwi   CLIMB    27,336 km  Petrol  KOLKATA
# ..            ...     ...   ...     ...          ...     ...      ...
# 275          2014  Honda   maze  1.5 SM  1,01,613 km  Diesel  KOLKATA
# 276          2019  Mahind  a XU  500 W7    10,833 km  Diesel  KOLKATA
# 277          2013  Maruti  Erti  a VDI     84,813 km  Diesel  KOLKATA
# 278          2011  Honda   ity    MT PE    99,510 km  Petrol  KOLKATA
# 279          2014  Honda   maze  1.2 VX  1,18,321 km  Petrol  KOLKATA
#
#          Owner     Price
# 0    1st Owner  2,62,899
# 1    1st Owner  4,18,599
# 2    2nd Owner  4,65,599
# ...

# %%
driver.get('https://www.cars24.com/buy-used-car?sort=P&storeCityId=5732&pinId=600001')
time.sleep(2)

# %%
### all car links
link_A = driver.find_elements_by_xpath('/html/body/div[1]/div[2]/div/div[3]/div[1]/div/div/a')
page2 = []
# here m rotating the loop to scrap 
for i in link_A:
    page2.append(i.get_attribute('href'))

# %%
page2
# Out:
# ['https://www.cars24.com/buy-used-Hyundai-i10-2014-cars-Chennai-1130119400/',
#  'https://www.cars24.com/buy-used-Maruti-S-PRESSO-2020-cars-Chennai-1131217203/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-2020-cars-Chennai-1137691009/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-2014-cars-Chennai-1136866924/',
#  'https://www.cars24.com/buy-used-Hyundai-i10-2011-cars-Chennai-1137744321/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-K10-2010-cars-Chennai-1135190424/',
#  'https://www.cars24.com/buy-used-Maruti-IGNIS-2019-cars-Chennai-1138369545/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-2011-cars-Chennai-1130168324/',
#  'https://www.cars24.com/buy-used-Maruti-Eeco-2015-cars-Chennai-1137363842/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-K10-2011-cars-Chennai-1130991741/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2017-cars-Chennai-1133409801/',
#  'https://www.cars24.com/buy-used-Hyundai-NEW-SANTRO-2018-cars-Chennai-1131047300/',
# ...

# %%
Brand = []
Model = []
Variant = []
Manufacturing = []
Kilometers = []
Fuel = []
Location = []
Price = []
Owner = []
for i in page2:
    driver.get(i)
    try:
        
        manufacturing = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/h2').text[0:4]
        brand = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/h2').text[5:11]
        model = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/h2').text[12:16]
        variant = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/h2').text[17:23]
        kilometer =driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[3]/div/div/div/div/ul/li[3]/strong').text
        fuel = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/ul/li[3]').text
        location = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[4]/div/div/div/div[1]/p/span').text
        price = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[3]/strong').text[10:18]
        owner = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[1]/div[2]/ul/li[5]').text
        Brand.append(brand)
        Model.append(model)
        Variant.append(variant)
        Kilometers.append(kilometer)
        Fuel.append(fuel)
        Location.append(location)
        Manufacturing.append(manufacturing)
        Owner.append(owner)
        Price.append(price)
    except NoSuchElementException:
        try:
            manufacturing = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/h2').text[0:4]
            brand = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/h2').text[5:11]
            model = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/h2').text[12:16]
            variant = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/h2').text[17:23]
            kilometer =driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/ul/li[1]').text
            fuel = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/ul/li[3]').text
            location = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[4]/div/div/div/div[1]/p/span').text
            price = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[2]/strong').text[10:18]
            owner = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div/div[1]/div[1]/ul/li[5]').text
            Brand.append(brand)
            Model.append(model)
            Variant.append(variant)
            Kilometers.append(kilometer)
            Fuel.append(fuel)
            Location.append(location)
            Manufacturing.append(manufacturing)
            Owner.append(owner)
            Price.append(price)
        except NoSuchElementException:
            Brand.append('--')
            Model.append('--')
            Variant.append('--')
            Kilometers.append('--')
            Fuel.append('--')
            Location.append('--')
            Manufacturing.append('--')
            Owner.append('--')
            Price.append('--')

# %%
csv5 = pd.DataFrame({
    'Manufacturing':Manufacturing,
    'Brand':Brand,
    'Model':Model,
    'Variant':Variant,
    'Kilometers':Kilometers,
    'Fuel':Fuel,
    'Location':Location,
    'Owner':Owner,
    'Price':Price
})

# %%
csv5
# Out:
#    Manufacturing   Brand Model Variant Kilometers    Fuel Location      Owner  \
# 0           2014  Hyunda   i10  MAGNA    2,876 km  Petrol  CHENNAI  1st Owner
# 1           2020  Maruti  S PR  SSO VX   3,171 km  Petrol  CHENNAI  1st Owner
# 2           2020  Maruti  Alto  LXI MA   3,494 km  Petrol  CHENNAI  1st Owner
# 3           2014  Maruti  Swif   VXI M   3,423 km  Petrol  CHENNAI  1st Owner
# 4           2011  Hyunda   i10  MAGNA   13,179 km  Petrol  CHENNAI  1st Owner
# 5           2010  Maruti  Alto  K10 LX  33,888 km  Petrol  CHENNAI  1st Owner
# 6           2019  Maruti  IGNI   DELTA   1,278 km  Petrol  CHENNAI  1st Owner
# 7           2011  Maruti  Alto  LXI MA  40,146 km  Petrol  CHENNAI  1st Owner
# 8           2015  Maruti  Eeco  5 STR   19,815 km  Petrol  CHENNAI  2nd Owner
# 9           2011  Maruti  Alto  K10 LX  42,789 km  Petrol  CHENNAI  2nd Owner
# 10          2017  Maruti  Alto  800 LX  12,389 km  Petrol  CHENNAI  1st Owner
# ...

# %%
car_csv = pd.concat([csv1, csv2,csv3,csv4,csv5], ignore_index=True)

# %%
car_csv
# Out:
#     Manufacturing   Brand Model Variant Kilometers    Fuel Location  \
# 0            2020  Maruti  S PR  SSO VX   3,176 km  Petrol    DELHI
# 1            2013  Maruti  Swif   ZDI M  24,022 km  Diesel    DELHI
# 2            2020  Maruti  S PR  SSO VX   7,556 km  Petrol    DELHI
# 3            2015  Maruti  Alto  800 LX   9,217 km  Petrol    DELHI
# 4            2017  Maruti  Alto  K10 VX  11,691 km  Petrol    DELHI
# ..            ...     ...   ...     ...        ...     ...      ...
# 715          2015  Hyunda   Eon  SPORTZ  15,346 km  Petrol  CHENNAI
# 716          2012  Maruti  Wago   R 1.0  38,553 km  Petrol  CHENNAI
# 717          2018  Tata T  ago   Z 1.2   12,997 km  Petrol  CHENNAI
# 718          2017  Maruti  Alto  800 VX  21,239 km  Petrol  CHENNAI
# 719          2017  Maruti  Wago   R 1.0  18,782 km  Petrol  CHENNAI
#
#          Owner     Price
# 0    1st Owner  4,02,199
# 1    1st Owner  3,96,599
# 2    1st Owner  4,01,899
# 3    1st Owner  2,58,599
# ...

# %%
car_csv.to_csv('cars.csv')

# %% [markdown]
# ##### START ML CODE

# %%
### import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from scipy import stats
from sklearn.preprocessing import StandardScaler

# %%
### load the data sets
Cars_df = pd.read_csv('cars.csv')

# %%
Cars_df
# Out:
#      Unnamed: 0 Manufacturing   Brand Model Variant   Kilometers    Fuel  \
# 0             0          2020  Maruti  S PR  SSO VX     3,176 km  Petrol
# 1             1          2013  Maruti  Swif   ZDI M    24,022 km  Diesel
# 2             2          2020  Maruti  S PR  SSO VX     7,556 km  Petrol
# 3             3          2015  Maruti  Alto  800 LX     9,217 km  Petrol
# 4             4          2017  Maruti  Alto  K10 VX    11,691 km  Petrol
# 5             5          2015  Honda   maze  1.2 VX    27,407 km  Petrol
# 6             6          2017  Maruti  Alto  800 LX     8,501 km  Petrol
# 7             7          2015  Maruti  Alto  800 LX    17,637 km  Petrol
# 8             8          2014  Maruti  Alto  800 VX    12,535 km  Petrol
# 9             9          2018  Renaul   Kwi   RXL M     8,220 km  Petrol
# 10           10          2013  Maruti  Alto  800 LX    10,111 km  Petrol
# 11           11          2010  Maruti  Alto  K10 VX    41,190 km  Petrol
# ...

# %% [markdown]
# #### EDA AND PREPROCESSING OF DATA

# %%
#### number of columns
df.columns
# Out:
# Index(['Unnamed: 0', 'Manufacturing', 'Brand', 'Model', 'Variant',
#        'Kilometers', 'Fuel', 'Location', 'Owner', 'Price'],
#       dtype='object')

# %%
#### data types 
Cars_df.dtypes
# Out:
# Unnamed: 0        int64
# Manufacturing    object
# Brand            object
# Model            object
# Variant          object
# Kilometers       object
# Fuel             object
# Location         object
# Owner            object
# Price            object
# dtype: object

# %%
#### km and price are numeric columns showing in object types so it can be fixed 
Cars_df['Kilometers'].replace('km','', regex=True, inplace=True)

# %%
Cars_df.replace(',','', regex=True, inplace=True)

# %%
Cars_df
# Out:
#      Unnamed: 0 Manufacturing   Brand Model Variant Kilometers    Fuel  \
# 0             0          2020  Maruti  S PR  SSO VX      3176   Petrol
# 1             1          2013  Maruti  Swif   ZDI M     24022   Diesel
# 2             2          2020  Maruti  S PR  SSO VX      7556   Petrol
# 3             3          2015  Maruti  Alto  800 LX      9217   Petrol
# 4             4          2017  Maruti  Alto  K10 VX     11691   Petrol
# 5             5          2015  Honda   maze  1.2 VX     27407   Petrol
# 6             6          2017  Maruti  Alto  800 LX      8501   Petrol
# 7             7          2015  Maruti  Alto  800 LX     17637   Petrol
# 8             8          2014  Maruti  Alto  800 VX     12535   Petrol
# 9             9          2018  Renaul   Kwi   RXL M      8220   Petrol
# 10           10          2013  Maruti  Alto  800 LX     10111   Petrol
# 11           11          2010  Maruti  Alto  K10 VX     41190   Petrol
# ...

# %%
#### check null columns
Cars_df.isnull().sum()
# Out:
# Unnamed: 0       0
# Manufacturing    0
# Brand            0
# Model            0
# Variant          0
# Kilometers       0
# Fuel             0
# Location         0
# Owner            0
# Price            0
# dtype: int64

# %%
### many columns found blank in all rows so i replace with nan to drop the nan columns directly
import numpy as np
Cars_df.replace('--','None', regex=True, inplace=True)

# %%
## fill NaN/None value with zero in km and price
Cars_df['Kilometers'].replace('None',0, regex=True, inplace=True)
Cars_df['Price'].replace('None',0, regex=True, inplace=True)

# %%
Cars_df['Price']= Cars_df['Price'].fillna(0)

# %%
Cars_df['Location']= Cars_df['Location'].fillna('None')

# %%
#### now replace ₹ sign from price if any one have
Cars_df.replace('₹','', regex=True, inplace=True)

# %%
### dropunamed columns which no use its unique and also level is unamed
Cars_df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
##### handle the missing /none value in int columns

# %%
### convert the columns as per theier type km and price is numeric so convet them into numeric it will helpfull to separate

# %%
Cars_df['Kilometers'] = pd.to_numeric(Cars_df['Kilometers'])

# %%
Cars_df['Price'] = pd.to_numeric(Cars_df['Price'])

# %%
Cars_df.dtypes
# Out:
# Unnamed: 0        int64
# Manufacturing    object
# Brand            object
# Model            object
# Variant          object
# Kilometers        int64
# Fuel             object
# Location         object
# Owner            object
# Price             int64
# dtype: object

# %%
##### find the catagorical value
columns = [columns for columns in Cars_df.columns if Cars_df[columns].dtypes=='object']
columns
# Out:
# ['Manufacturing', 'Brand', 'Model', 'Variant', 'Fuel', 'Location', 'Owner']

# %%
Cars_df_cat = Cars_df[columns]

# %%
Cars_df_cat
# Out:
#     Manufacturing   Brand Model Variant    Fuel   Location      Owner
# 0            2020  Maruti  S PR  SSO VX  Petrol      DELHI  1st Owner
# 1            2013  Maruti  Swif   ZDI M  Diesel      DELHI  1st Owner
# 2            2020  Maruti  S PR  SSO VX  Petrol      DELHI  1st Owner
# 3            2015  Maruti  Alto  800 LX  Petrol      DELHI  1st Owner
# 4            2017  Maruti  Alto  K10 VX  Petrol      DELHI  1st Owner
# 5            2015  Honda   maze  1.2 VX  Petrol      DELHI  1st Owner
# 6            2017  Maruti  Alto  800 LX  Petrol      DELHI  1st Owner
# 7            2015  Maruti  Alto  800 LX  Petrol      DELHI  1st Owner
# 8            2014  Maruti  Alto  800 VX  Petrol      DELHI  1st Owner
# 9            2018  Renaul   Kwi   RXL M  Petrol      DELHI  1st Owner
# 10           2013  Maruti  Alto  800 LX  Petrol      DELHI  1st Owner
# 11           2010  Maruti  Alto  K10 VX  Petrol      DELHI  1st Owner
# ...

# %%
##### find the continous columns
count_col = [count_col for count_col in Cars_df.columns if Cars_df[count_col].dtypes!='object']
count_col
# Out:
# ['Kilometers', 'Price']

# %%
Cars_df_cont = Cars_df[count_col]

# %%
Cars_df_cont
# Out:
#      Kilometers   Price
# 0          3176  402199
# 1         24022  396599
# 2          7556  401899
# 3          9217  258599
# 4         11691  345699
# 5         27407  453399
# 6          8501  293799
# 7         17637  278799
# 8         12535  293599
# 9          8220  314199
# 10        10111  227899
# 11        41190  180599
# 12        34364  369499
# 13        20039  199599
# 14         7610  357099
# 15        10608  300899
# 16        46475  265299
# 17        10155  311099
# 18         3570  566899
# 19        25610  199099
# 20         9527  290699
# 21         1441  600699
# 22        22836  376999
# 23        35139  201699
# 24         7093  313399
# 25        20231  289299
# 26        12501  222699
# 27        13289       0
# 28        17374  230099
# 29        15471  350699
# 30        43114  376999
# 31        29645  174699
# 32        12808  418599
# 33        28704  351899
# 34         1755  566399
# 35        49654  318299
# 36        30737  524799
# ...

# %%
Cars_df.columns
# Out:
# Index(['Manufacturing', 'Brand', 'Model', 'Variant', 'Kilometers', 'Fuel',
#        'Location', 'Owner', 'Price'],
#       dtype='object')

# %%
##### Visalization
#### Bar Plot 
plt.figure(figsize=(25,10))
sns.countplot(x=Cars_df['Brand'])
plt.show()

# %%
#### maruti is height like brand in all locations

# %%
#### Bar Plot 
plt.figure(figsize=(25,10))
sns.countplot(x=Cars_df['Fuel'])
plt.show()

# %%
### mostly petrol engine cars are seems to be in all location to sell

# %%
plt.figure(figsize=(25,10))
sns.barplot(x=Cars_df['Brand'],y=Cars_df['Kilometers'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#### highest km cover brand is Fiat A

# %%
plt.figure(figsize=(25,10))
sns.barplot(x=Cars_df['Brand'],y=Cars_df['Price'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#### brand wise more price is of FORD than tata in 2nd and in 3rd Honda

# %%
#### Bar Plot 
plt.figure(figsize=(25,10))
sns.countplot(x=Cars_df['Owner'])
plt.show()

# %%
### it is good that mostly first owner car is on sale

# %%
### check the outliers using boxplot
#### check the presence of outliers
for i in count_col:
    sns.boxplot(Cars_df[i])
    plt.show()

# %%
### i will not remove the outliers because it can an be run as much as km and its price can also be increased no limit

# %%
#### lets check the skewness for continous columns in train dataset
for i in count_col:
    sns.distplot(Cars_df[i])
    plt.show()

# %%
#### now apply label Encoder in Catagorical value
from sklearn.preprocessing import LabelEncoder
Le = LabelEncoder()

# %%
for i in Cars_df_cat:
    Cars_df_cat[i] = Le.fit_transform(Cars_df_cat[i])

# %%
Cars_df_cat
# Out:
#      Manufacturing  Brand  Model  Variant  Fuel  Location  Owner
# 0               12     10     37       67     2         2      0
# 1                5     10     38       25     0         2      0
# 2               12     10     37       67     2         2      0
# 3                7     10     18       44     2         2      0
# 4                9     10     18       60     2         2      0
# 5                7      6     54       36     2         2      0
# 6                9     10     18       44     2         2      0
# 7                7     10     18       44     2         2      0
# 8                6     10     18       45     2         2      0
# 9               10     12      9       14     2         2      0
# 10               5     10     18       44     2         2      0
# 11               2     10     18       60     2         2      0
# 12               4     17     50      103     2         2      0
# ...

# %%
### for continous columns i will aplly standard scaler to normalize
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
### drop the target columns
Cars_df_cont.drop(['Price'],axis=1,inplace=True)

# %%
scaled = sc.fit_transform(Cars_df_cont)

# %%
Cars_df_cont = pd.DataFrame(scaled,columns=['Kilometers'])

# %%
Cars_df_cont
# Out:
#      Kilometers
# 0     -1.112514
# 1     -0.237308
# 2     -0.928622
# 3     -0.858886
# 4     -0.755017
# 5     -0.095192
# 6     -0.888947
# 7     -0.505378
# 8     -0.719582
# 9     -0.900745
# 10    -0.821352
# 11     0.483478
# 12     0.196893
# 13    -0.404532
# 14    -0.926355
# 15    -0.800486
# 16     0.705366
# 17    -0.819505
# 18    -1.095972
# 19    -0.170637
# 20    -0.845871
# 21    -1.185357
# 22    -0.287102
# 23     0.229431
# 24    -0.948061
# 25    -0.396471
# 26    -0.721010
# 27    -0.687926
# 28    -0.516420
# 29    -0.596316
# 30     0.564256
# 31    -0.001231
# 32    -0.708121
# 33    -0.040738
# 34    -1.172173
# 35     0.838834
# 36     0.044616
# 37    -0.565710
# 38    -0.146580
# 39    -0.753758
# 40     0.557833
# 41    -0.743681
# 42     1.114965
# 43    -0.339372
# 44    -0.584603
# 45    -0.736208
# 46     0.484444
# 47     0.001037
# 48    -0.073863
# 49    -0.091707
# 50    -0.185584
# 51    -0.889409
# 52    -0.730792
# 53     0.441242
# ...

# %%
### Create new Data Frame
Cars_df_new = pd.concat([Cars_df_cat,Cars_df_cont],axis = 1)

# %%
Cars_df_new
# Out:
#      Manufacturing  Brand  Model  Variant  Fuel  Location  Owner  Kilometers
# 0               12     10     37       67     2         2      0   -1.112514
# 1                5     10     38       25     0         2      0   -0.237308
# 2               12     10     37       67     2         2      0   -0.928622
# 3                7     10     18       44     2         2      0   -0.858886
# 4                9     10     18       60     2         2      0   -0.755017
# 5                7      6     54       36     2         2      0   -0.095192
# 6                9     10     18       44     2         2      0   -0.888947
# 7                7     10     18       44     2         2      0   -0.505378
# 8                6     10     18       45     2         2      0   -0.719582
# 9               10     12      9       14     2         2      0   -0.900745
# 10               5     10     18       44     2         2      0   -0.821352
# ...

# %%
#### target columns
y= df['Price']

# %%
#### Model building
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import GradientBoostingRegressor,RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
rf=RandomForestRegressor()
dtc = DecisionTreeRegressor()
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
y = Cars_df['Price']
x = Cars_df_new

# %%
x.shape
# Out:
# (720, 8)

# %%
y.shape
# Out:
# (720,)

# %%
### find the best accuracy
maxAcc=0
maxRs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
   # print(f"At Random State {i},the tarining accuracy is :- ",{r2_score(y_train,pred_train)})
   # print(f"At Random State {i},the Test accuracy is :- ",{r2_score(y_test,pred_test)})
    accu = r2_score(y_test,pred_test)
    if accu>maxAcc:
        maxAcc=accu
        maxRs=i
print("Best accuracy -",maxAcc,'Best Random state = ',maxRs)
# Out:
# Best accuracy - 0.4381943345303301 Best Random state =  80

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=127)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
def predict(ml_model):
    print('Model is : {}'.format(ml_model))
    model = ml_model.fit(x_train,y_train)
    print("Training Score : {}".format(model.score(x_train,y_train)))
    predictions = model.predict(x_test)
    print("Predictions are : {}" ,format(predictions))
    print('\n')
    print('Prediction')
    r2score = r2_score(y_test,predictions)
    print("r2 Score is : {}",format(r2score))
    print('Cross Validation Score: {}'.format(cross_val_score(ml_model,x_train,y_train,cv=5,scoring='r2')))
    print('MAE: {}'.format(mean_absolute_error(y_test,predictions)))
    print('MSE: {}'.format(mean_squared_error(y_test,predictions)))
    print('RMSE: {}'.format(np.sqrt(mean_squared_error(y_test,predictions))))
    print('\n')   
    
    sns.distplot(y_test-predictions)

# %%
predict(LinearRegression())
# Out:
# Model is : LinearRegression()
# Training Score : 0.24487500610514024
# Predictions are : {} [322059.62929815 398512.04136057 267434.02881334 348274.7330464
#  408707.984826   249772.118612   330566.72419996 244976.69950432
#  377510.71097022 268296.04914844 487753.99229057 246760.3599226
#  405444.64529345 419844.81558551 500789.44078272 316896.75761041
#  303153.97905031 221442.92587867 297177.98443639 335085.40307688
#  359668.83777164 387202.39685031 353894.22203977 406592.10170185
#  280795.31202909 579420.87424057 278673.9704594  372180.01595604
#  384159.04628548 357580.33508702 342422.98878102 270467.86902709
#  520119.37530588 340261.00106718 357706.94719238 291141.08691069
#  376703.07824404 391237.41854298 319444.77477303 416585.47568035
#  453142.4379163  329741.20063768 404899.60566847 363018.10223
#  340555.01565343 189857.93155983 331378.76188645 470387.45384672
#  326751.37187503 301086.65505666 381300.53208778 269751.74700585
# ...

# %%
predict(RandomForestRegressor())
# Out:
# Model is : RandomForestRegressor()
# Training Score : 0.9505658417380555
# Predictions are : {} [271777.03 348809.   369342.04 391283.07 308515.   130992.1  281369.
#  318885.   313242.   241105.   271681.61 201161.3  480657.   374376.
#  611021.62 541955.04 222970.    44382.64 283801.02 306276.04 457653.
#  295392.03   4021.99 325123.   361875.02 641697.7  285269.   500844.8
#  379432.02 442133.01 396393.47 367685.02 457397.   305383.   457321.09
#  266384.   513847.   344478.   291459.   615349.04 553131.   425459.03
#  331912.76 276592.   372902.   305079.   280611.02 530943.   379419.01
#  312705.   532173.05 235740.   291763.   239721.01 340469.01 365724.
#  425159.   470363.   274367.01 222242.   385034.27 506970.   387278.03
#  463331.1  369583.   427992.   458901.   292755.   407239.08 221000.
#  360457.   339435.01 397909.02 264519.   415525.   295606.01 314442.
#  372828.09 378401.   758925.   369837.01 331437.   276268.   226770.12
# ...

# %%
from sklearn.neighbors import KNeighborsRegressor
predict(KNeighborsRegressor())
# Out:
# Model is : KNeighborsRegressor()
# Training Score : 0.6911280344420363
# Predictions are : {} [268219.  510319.  286479.2 420999.2 299759.  105199.4 289419.  315619.
#  315219.  234179.  327301.  258959.4 470639.  354679.  622559.  420999.2
#  188899.2 128319.2 270579.  251139.2 361519.  241399.2  80439.8 397741.
#  353219.  462199.  279019.  572739.  382159.  461519.  420999.2 359579.2
#  413819.  296119.  432339.  209139.  446519.  272959.2 263319.  597799.
#  514579.  456139.  320519.  287159.  368879.  419599.  235719.2 514839.
#  378499.  263319.  600459.2 248499.  306779.  163319.2 302219.  368879.
#  440019.  431139.  251359.  229219.  325159.2 537099.  394079.  536359.
#  343739.  434639.  472619.  296639.  268119.4 236079.  382159.  272959.2
#  400579.  281859.  244999.  281659.  317139.  374059.2 351359.  503799.
#  442419.  342159.  366779.  421699.  537099.  345939.  583019.  170539.2
#  346879.  616419.  344459.  251139.2 382159.  105199.4 314299.2 312819.
# ...

# %%
predict(GradientBoostingRegressor())
# Out:
# Model is : GradientBoostingRegressor()
# Training Score : 0.8565654931384086
# Predictions are : {} [278026.70266453 343361.79964452 408268.33089566 398823.39008737
#  319547.51986191 154492.02920492 282497.20498893 321335.94864851
#  317140.95296837 239429.65542391 300651.72558307 212924.07949999
#  499256.94937764 356093.22106349 584792.73793796 503438.33157252
#  193394.30361062 147025.70115501 282734.07202344 332880.07753004
#  422947.36711164 279613.60586549  20347.67713898 218264.30371405
#  339224.62892837 670660.01044893 268874.81833811 520117.78199932
#  385920.72561524 404844.23949862 381554.71668759 342633.3355058
#  447139.41486272 303098.02780091 443072.25127919 257592.04420621
#  469111.33419458 327157.29949624 237901.43801197 595697.23967196
#  507028.39646381 403854.11481177 337168.72543581 313070.90938682
#  341233.76407753 305597.34738961 268827.00052689 473481.04247089
#  379873.00241172 239631.60962722 540461.85265558 234603.7910641
# ...

# %%
predict(DecisionTreeRegressor())
# Out:
# Model is : DecisionTreeRegressor()
# Training Score : 1.0
# Predictions are : {} [298499. 369499. 474499. 404499. 322599. 160399. 289699. 326899. 322599.
#  227899.  10309. 210799. 479899. 411999. 620499. 641199. 223299.      0.
#  298499. 310499. 477899. 292499.      0. 319599. 327999. 639099. 286399.
#  650499. 418599. 456899. 385000. 346199. 468599. 300099. 612499. 259599.
#  531099. 348599. 241799. 680799. 574299. 456899. 343499. 282699. 389499.
#  318299. 286799. 582199. 399499. 263999. 488199. 230099. 293799. 158899.
#  208399. 389499. 474199. 466399. 298499. 213399. 745599. 508899. 384099.
#  612499. 368799. 410299. 418599. 293799. 439799. 204999. 343699. 348599.
#  356799. 225099. 629199. 289299. 314199. 376999. 389499. 868199. 358599.
#  383799. 289499. 199599. 504799. 386899. 635699. 200899.      0. 601599.
#  349399. 310499. 392699. 148099. 343599. 304399. 584299. 769899. 270399.
#  378499. 228299. 300099. 601599. 586599. 474199. 356799. 342099. 745599.
# ...

# %%
from sklearn.ensemble import ExtraTreesRegressor
predict(ExtraTreesRegressor())
# Out:
# Model is : ExtraTreesRegressor()
# Training Score : 0.9999999589750629
# Predictions are : {} [268545.04 345818.   294835.31 415660.   325358.   130141.2  290662.
#  318376.   312631.   234020.   126543.   202662.14 477481.   361706.
#  628393.9  421175.06 163928.25  49595.74 298499.   310499.   477899.
#  301307.        0.   317351.58 334723.   645365.   286399.   512503.
#  366252.   436972.   411293.06 343836.01 477209.   300099.   474763.08
#  233330.   531099.   343708.   237446.   622227.06 568160.   450321.
#  341713.   285016.   369421.01 314588.   284093.   511776.   355207.06
#  247214.05 495933.   233843.   290197.   210915.   301422.   368716.86
#  457555.   466399.   263684.   212860.   547467.13 502831.   393351.05
#  538387.01 366082.   418622.   485073.   296347.   440383.   205412.03
#  351470.   343708.   435847.02 251293.   256973.   282659.01 315017.
#  373221.09 370863.   774198.   358599.   358998.   283761.   241309.
# ...

# %%
gdb = GradientBoostingRegressor()
gdb.fit(x_train,y_train)
pred_test=gdb.predict(x_test)
pred_train=gdb.predict(x_train)

# %%
plt.figure(figsize=(8,7))
plt.scatter(x=y_test,y=pred_test,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual Charges',fontsize=14)
plt.ylabel('Predicted Charges',fontsize=14)
plt.title('Gredident Tres Regression',fontsize=18)
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {
    "n_estimators":[5,50,250,500],
    "max_depth":[1,3,5,7,9],
    "learning_rate":[0.01,0.1,1,10,100]
}

# %%
GCV=GridSearchCV(GradientBoostingRegressor(),parameters,cv=5)
GCV.fit(x_train,y_train)

GCV.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}

# %%
Final_model=GradientBoostingRegressor(learning_rate=0.1,max_depth=2,n_estimators=500)
Final_model.fit(x_train,y_train)
pred=Final_model.predict(x_test)
accuracy = r2_score(y_test,pred)
print(accuracy*100)
# Out:
# 64.12066318624335

# %%
#### accuracy has been increased
