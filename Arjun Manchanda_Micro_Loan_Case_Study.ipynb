# %% [raw]
# # Description
# #loan. In this case, Label ‘1’ indicates that the loan has been payed i.e. Non- defaulter, while, Label ‘0’ indicates that the loan has not been payed i.e. defaulter.
# #Points toRemember:
# #	There are no null values in the dataset.
# #	There may be some customers with no loan history.
# #	The dataset is imbalanced. Label ‘1’ has approximately 87.5% records, while, label ‘0’ has approximately 12.5% records.
# #	For some features, there may be values which might not be realistic. You may have to observe them and treat them with a suitable explanation.
# #	You might come across outliers in some features which you need to handle as per your understanding. Keep in mind that data is expensive and we cannot lose more than 7-8% of the data.

# %% [markdown]
# Importing Basic Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Collection

# %%
Micro_Loan_df=pd.read_csv('Data file.csv')

# %%
Micro_Loan_df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %% [markdown]
# In above Dataset Unnamed column ,pcircle column is not effect if they will drop both are not connected with others columns
# split date column in day month and year

# %%
Micro_Loan_df.drop(['Unnamed: 0','pcircle'],axis=1,inplace=True)

# %%
Micro_Loan_df
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 0           0  21408I70789   272.0   3055.050000   3065.150000    220.13
# 1           1  76462I70374   712.0  12122.000000  12124.750000   3691.26
# 2           1  17943I70372   535.0   1398.000000   1398.000000    900.13
# 3           1  55773I70781   241.0     21.228000     21.228000    159.42
# 4           1  03813I82730   947.0    150.619333    150.619333   1098.90
# ...       ...          ...     ...           ...           ...       ...
# 209588      1  22758I85348   404.0    151.872333    151.872333   1089.19
# 209589      1  95583I84455  1075.0     36.936000     36.936000   1728.36
# 209590      1  28556I85350  1013.0  11843.111667  11904.350000   5861.83
# 209591      1  59712I82733  1732.0  12488.228333  12574.370000    411.83
# 209592      1  65061I85339  1581.0   4489.362000   4534.820000    483.92
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# ...

# %%
df[["year", "month", "day"]] = df["pdate"].str.split("-", expand = True)

# %%
df
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 0           0  21408I70789   272.0   3055.050000   3065.150000    220.13
# 1           1  76462I70374   712.0  12122.000000  12124.750000   3691.26
# 2           1  17943I70372   535.0   1398.000000   1398.000000    900.13
# 3           1  55773I70781   241.0     21.228000     21.228000    159.42
# 4           1  03813I82730   947.0    150.619333    150.619333   1098.90
# ...       ...          ...     ...           ...           ...       ...
# 209588      1  22758I85348   404.0    151.872333    151.872333   1089.19
# 209589      1  95583I84455  1075.0     36.936000     36.936000   1728.36
# 209590      1  28556I85350  1013.0  11843.111667  11904.350000   5861.83
# 209591      1  59712I82733  1732.0  12488.228333  12574.370000    411.83
# 209592      1  65061I85339  1581.0   4489.362000   4534.820000    483.92
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# ...

# %% [markdown]
# Now p_date has been separated into day month and year,so p_date will be droped now

# %%
Micro_Loan_df['year'].unique
# Out:
# <bound method Series.unique of 0         2016
# 1         2016
# 2         2016
# 3         2016
# 4         2016
#           ...
# 209588    2016
# 209589    2016
# 209590    2016
# 209591    2016
# 209592    2016
# Name: year, Length: 209593, dtype: object>

# %%
Micro_Loan_df.drop(['pdate','year'],axis=1,inplace=True)
Micro_Loan_df
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 0           0  21408I70789   272.0   3055.050000   3065.150000    220.13
# 1           1  76462I70374   712.0  12122.000000  12124.750000   3691.26
# 2           1  17943I70372   535.0   1398.000000   1398.000000    900.13
# 3           1  55773I70781   241.0     21.228000     21.228000    159.42
# 4           1  03813I82730   947.0    150.619333    150.619333   1098.90
# ...       ...          ...     ...           ...           ...       ...
# 209588      1  22758I85348   404.0    151.872333    151.872333   1089.19
# 209589      1  95583I84455  1075.0     36.936000     36.936000   1728.36
# 209590      1  28556I85350  1013.0  11843.111667  11904.350000   5861.83
# 209591      1  59712I82733  1732.0  12488.228333  12574.370000    411.83
# 209592      1  65061I85339  1581.0   4489.362000   4534.820000    483.92
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# msisdn is in string so need to encode in number

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
Micro_Loan_df['msisdn']=le.fit_transform(Micro_Loan_df['msisdn']);

# %%
Micro_Loan_df
# Out:
#         label  msisdn     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   40191   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1  142291   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   33594   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1  104157   241.0     21.228000     21.228000    159.42    159.42
# 4           1    6910   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...     ...           ...           ...       ...       ...
# 209588      1   42866   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  178248  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1   53995  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  111388  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  121263  1581.0   4489.362000   4534.820000    483.92    631.20
#
# ...

# %%
Micro_Loan_df.isnull().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# month                   0
# ...

# %% [markdown]
# No Missing value is in dataset

# %%
Micro_Loan_df.dtypes
# Out:
# label                     int64
# msisdn                    int32
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# cnt_loans90             float64
# ...

# %% [markdown]
# day and month is in catagorical from

# %% [markdown]
# # Data Analysis & Visualisation

# %%
sns.heatmap(Micro_Loan_df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Univariate Analysis

# %%
columns=['aon', 'daily_decr30', 'daily_decr90', 'rental30',
    'rental90', 'last_rech_date_ma', 'last_rech_date_da',
       'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
       'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
       'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
       'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
       'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
       'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
       'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
       'payback90']

# %%
Micro_Loan_df
# Out:
#         label  msisdn     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   40191   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1  142291   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   33594   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1  104157   241.0     21.228000     21.228000    159.42    159.42
# 4           1    6910   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...     ...           ...           ...       ...       ...
# 209588      1   42866   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  178248  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1   53995  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  111388  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  121263  1581.0   4489.362000   4534.820000    483.92    631.20
#
# ...

# %%
for col in Micro_Loan_df:
    sns.boxplot(Micro_Loan_df[col])
    plt.show()

# %% [markdown]
# Outliers are showing using boxplot

# %% [markdown]
# label is target variable

# %%
sns.countplot(Micro_Loan_df['label'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %% [markdown]
# class imbalance is there

# %%
Micro_Loan_df['label'].value_counts()
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %% [markdown]
# Bivariate Analysis

# %%
plt.title('Comparision between daily_decr30 and daily_decr90')
sns.scatterplot(x=Micro_Loan_df['daily_decr30'], y=Micro_Loan_df['daily_decr90'],hue=Micro_Loan_df['label'])
# Out:
# <AxesSubplot:title={'center':'Comparision between daily_decr30 and daily_decr90'}, xlabel='daily_decr30', ylabel='daily_decr90'>

# %% [markdown]
# Flag indicating whether the user paid back the credit amount within 5 days of issuing the loan{1:success, 0:failure}
#
# daily_decr30 Daily amount spent from main account, averaged over last 30 days (in Indonesian Rupiah)
#
# daily_decr90 Daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah)

# %%
plt.title('Comparision between daily_decr30 and daily_decr90')
sns.scatterplot(x=Micro_Loan_df['rental30'], y=Micro_Loan_df['rental90'],hue=Micro_Loan_df['label'])
# Out:
# <AxesSubplot:title={'center':'Comparision between daily_decr30 and daily_decr90'}, xlabel='rental30', ylabel='rental90'>

# %% [markdown]
# rental30 Average main account balance over last 30 days rental90 Average main account balance over last 90 days realtionship between both rental30 and rental90 is more success

# %%
plt.title('Comparision between cnt_ma_rech30 and fr_ma_rech30')
sns.scatterplot(x=Micro_Loan_df['cnt_ma_rech30'], y=Micro_Loan_df['fr_ma_rech30'],hue=Micro_Loan_df['label'])
# Out:
# <AxesSubplot:title={'center':'Comparision between cnt_ma_rech30 and fr_ma_rech30'}, xlabel='cnt_ma_rech30', ylabel='fr_ma_rech30'>

# %% [markdown]
# cnt_ma_rech30 Number of times main account got recharged in last 30 days fr_ma_rech30 Frequency of main account recharged in last 30 days
#
# both have success rate bewteen 0.5 to 1.0 is success but outliers is also there to see

# %%
plt.title('Comparision between last_rech_amt_ma and last_rech_date_da')
sns.scatterplot(x=Micro_Loan_df['last_rech_amt_ma'], y=Micro_Loan_df['last_rech_date_da'],hue=Micro_Loan_df['label'])
# Out:
# <AxesSubplot:title={'center':'Comparision between last_rech_amt_ma and last_rech_date_da'}, xlabel='last_rech_amt_ma', ylabel='last_rech_date_da'>

# %% [markdown]
# last_rech_date_da Number of days till last recharge of data account last_rech_amt_ma Amount of last recharge of main account (in Indonesian Rupiah) both have success rate bewteen 0.5 to 1.0 is success but outliers is also there to see because points are carrying a much heavier backpack than the pattern predicts.

# %%
plt.title('Comparision between cnt_loans30 and amnt_loans30')
sns.scatterplot(x=Micro_Loan_df['cnt_loans30'], y=Micro_Loan_Micro_Loan_df['amnt_loans30'],hue=Micro_Loan_df['label'])
# Out:
# <AxesSubplot:title={'center':'Comparision between cnt_loans30 and amnt_loans30'}, xlabel='cnt_loans30', ylabel='amnt_loans30'>

# %% [markdown]
# cnt_loans30 Number of loans taken by user in last 30 days amnt_loans30 Total amount of loans taken by user in last 30 days
#
# Number of loans taken by user in last 30 days and number of total amount of loans by user in 30 days (success rate is good)

# %% [markdown]
# Multivaruate Analysis

# %%
sns.pairplot(Micro_Loan_df)

# %%
cor=Micro_Loan_df.corr()
cor
# Out:
#                          label    msisdn       aon  daily_decr30  \
# label                 1.000000  0.001976 -0.003785      0.168298
# msisdn                0.001976  1.000000  0.000566      0.000717
# aon                  -0.003785  0.000566  1.000000      0.001104
# daily_decr30          0.168298  0.000717  0.001104      1.000000
# daily_decr90          0.166150  0.000950  0.000374      0.977704
# rental30              0.058085 -0.001404 -0.000960      0.442066
# rental90              0.075521 -0.000691 -0.000790      0.458977
# last_rech_date_ma     0.003728 -0.000928  0.001692      0.000487
# last_rech_date_da     0.001711  0.001400 -0.001693     -0.001636
# last_rech_amt_ma      0.131804 -0.002368  0.004256      0.275837
# cnt_ma_rech30         0.237331  0.000617 -0.003148      0.451385
# fr_ma_rech30          0.001330 -0.001804 -0.001163     -0.000577
# sumamnt_ma_rech30     0.202828  0.001094  0.000707      0.636536
# ...

# %% [markdown]
# corelation between all data present in dataset

# %%
plt.figure(figsize=(20,20))
sns.heatmap(cor,annot=True)
plt.show()

# %% [markdown]
# # Feature Selection & Engineering

# %% [markdown]
# divide the target and feature columns

# %%
x=Micro_Loan_df.drop(['label','month','day','last_rech_date_da'],axis=1); #month and day also in categorial form thats why eliminate
y=Micro_Loan_df['label']

# %%
x
# Out:
#         msisdn     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0        40191   272.0   3055.050000   3065.150000    220.13    260.13
# 1       142291   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2        33594   535.0   1398.000000   1398.000000    900.13    900.13
# 3       104157   241.0     21.228000     21.228000    159.42    159.42
# 4         6910   947.0    150.619333    150.619333   1098.90   1098.90
# ...        ...     ...           ...           ...       ...       ...
# 209588   42866   404.0    151.872333    151.872333   1089.19   1089.19
# 209589  178248  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590   53995  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591  111388  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592  121263  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  ...  \
# ...

# %%
y
# Out:
# 0         0
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 209588    1
# 209589    1
# 209590    1
# 209591    1
# 209592    1
# Name: label, Length: 209593, dtype: int64

# %%
x.columns
# Out:
# Index(['msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
#        'last_rech_date_ma', 'last_rech_amt_ma', 'cnt_ma_rech30',
#        'fr_ma_rech30', 'sumamnt_ma_rech30', 'medianamnt_ma_rech30',
#        'medianmarechprebal30', 'cnt_ma_rech90', 'fr_ma_rech90',
#        'sumamnt_ma_rech90', 'medianamnt_ma_rech90', 'medianmarechprebal90',
#        'cnt_da_rech30', 'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90',
#        'cnt_loans30', 'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30',
#        'cnt_loans90', 'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90',
#        'payback30', 'payback90'],
#       dtype='object')

# %%
Micro_Loan_df.shape
# Out:
# (209593, 36)

# %%
x.shape
# Out:
# (209593, 32)

# %% [markdown]
# 3 columns i have droped

# %% [markdown]
# Handling the class imbalance by oversampling the minority class

# %%
#!pip install imblearn
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
ros=RandomOverSampler(random_state=42)
x_over,y_over=ros.fit_resample(x,y)
print('Print Original Dataset',Counter(y))
print('Print Original Dataset',Counter(y_over))
# Out:
# Print Original Dataset Counter({1: 183431, 0: 26162})
# Print Original Dataset Counter({0: 183431, 1: 183431})

# %% [markdown]
# balancing the class using oversampling

# %% [markdown]
# zscore and ouliers

# %%
import sklearn
from scipy.stats import zscore
z=np.abs(zscore(x))
z
# Out:
# array([[0.984213  , 0.10357685, 0.25229941, ..., 0.22959366, 2.9046997 ,
#         2.39409346],
#        [0.91502744, 0.09776412, 0.73103667, ..., 0.22959366, 0.38562959,
#         0.41923266],
#        [1.10692885, 0.10010243, 0.43201111, ..., 0.22959366, 0.38562959,
#         0.41923266],
#        ...,
#        [0.7274342 , 0.09378769, 0.70079045, ..., 0.22959366, 0.06820893,
#         0.04735622],
#        [0.34017702, 0.08428915, 0.77075515, ..., 0.22959366, 0.38562959,
#         0.59938541],
#        [0.52386948, 0.08628398, 0.09674426, ..., 0.22959366, 0.38562959,
#         0.41923266]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([    21,     22,     22, ..., 209586, 209587, 209587], dtype=int64), array([14, 14, 31, ..., 27, 25, 29], dtype=int64))

# %% [markdown]
# outliers showing

# %% [markdown]
# Check the Preference of outliers

# %%
print('shape before removing the outliers :',x.shape)

dsnew=x[(z<3).all(axis=1)]


print('Shape after removing the ouliers :',dsnew.shape)
# Out:
# shape before removing the outliers : (209593, 32)
# Shape after removing the ouliers : (162258, 32)

# %% [markdown]
# After Removing Outliers loss of data is more

# %%
x.describe()
# Out:
#               msisdn            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean    93100.650179    8112.343445    5381.402289    6082.515068
# std     53758.461427   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%     46506.000000     246.000000      42.440000      42.692000
# 50%     93073.000000     527.000000    1469.175667    1500.000000
# 75%    139626.000000     982.000000    7244.000000    7802.790000
# max    186242.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_amt_ma  \
# count  209593.000000  209593.000000      209593.000000     209593.000000
# mean     2692.581910    3483.406534        3755.847800       2064.452797
# std      4308.586781    5770.461279       53905.892230       2370.786034
# min    -23737.140000  -24720.580000         -29.000000          0.000000
# ...

# %% [markdown]
# Try IQR method to see the outliers

# %%
quantile1=Micro_Loan_df.quantile(0.75)

# %%
quantile1
# Out:
# label                        1.00
# msisdn                  139626.00
# aon                        982.00
# daily_decr30              7244.00
# daily_decr90              7802.79
# rental30                  3356.94
# rental90                  4201.79
# last_rech_date_ma            7.00
# last_rech_date_da            0.00
# last_rech_amt_ma          2309.00
# cnt_ma_rech30                5.00
# fr_ma_rech30                 6.00
# sumamnt_ma_rech30        10010.00
# medianamnt_ma_rech30      1924.00
# medianmarechprebal30        83.00
# cnt_ma_rech90                8.00
# fr_ma_rech90                 8.00
# sumamnt_ma_rech90        16000.00
# medianamnt_ma_rech90      1924.00
# medianmarechprebal90        79.31
# cnt_da_rech30                0.00
# fr_da_rech30                 0.00
# cnt_da_rech90                0.00
# fr_da_rech90                 0.00
# cnt_loans30                  4.00
# amnt_loans30                24.00
# maxamnt_loans30              6.00
# ...

# %%
quantile3=Micro_Loan_df.quantile(0.25)

# %%
quantile3
# Out:
# label                       1.000
# msisdn                  46506.000
# aon                       246.000
# daily_decr30               42.440
# daily_decr90               42.692
# rental30                  280.420
# rental90                  300.260
# last_rech_date_ma           1.000
# last_rech_date_da           0.000
# last_rech_amt_ma          770.000
# cnt_ma_rech30               1.000
# fr_ma_rech30                0.000
# sumamnt_ma_rech30        1540.000
# medianamnt_ma_rech30      770.000
# medianmarechprebal30       11.000
# cnt_ma_rech90               2.000
# fr_ma_rech90                0.000
# sumamnt_ma_rech90        2317.000
# medianamnt_ma_rech90      773.000
# medianmarechprebal90       14.600
# cnt_da_rech30               0.000
# fr_da_rech30                0.000
# cnt_da_rech90               0.000
# fr_da_rech90                0.000
# cnt_loans30                 1.000
# amnt_loans30                6.000
# maxamnt_loans30             6.000
# ...

# %%
quantile1
# Out:
# label                        1.00
# msisdn                  139626.00
# aon                        982.00
# daily_decr30              7244.00
# daily_decr90              7802.79
# rental30                  3356.94
# rental90                  4201.79
# last_rech_date_ma            7.00
# last_rech_date_da            0.00
# last_rech_amt_ma          2309.00
# cnt_ma_rech30                5.00
# fr_ma_rech30                 6.00
# sumamnt_ma_rech30        10010.00
# medianamnt_ma_rech30      1924.00
# medianmarechprebal30        83.00
# cnt_ma_rech90                8.00
# fr_ma_rech90                 8.00
# sumamnt_ma_rech90        16000.00
# medianamnt_ma_rech90      1924.00
# medianmarechprebal90        79.31
# cnt_da_rech30                0.00
# fr_da_rech30                 0.00
# cnt_da_rech90                0.00
# fr_da_rech90                 0.00
# cnt_loans30                  4.00
# amnt_loans30                24.00
# maxamnt_loans30              6.00
# ...

# %%
quantile3
# Out:
# label                       1.000
# msisdn                  46506.000
# aon                       246.000
# daily_decr30               42.440
# daily_decr90               42.692
# rental30                  280.420
# rental90                  300.260
# last_rech_date_ma           1.000
# last_rech_date_da           0.000
# last_rech_amt_ma          770.000
# cnt_ma_rech30               1.000
# fr_ma_rech30                0.000
# sumamnt_ma_rech30        1540.000
# medianamnt_ma_rech30      770.000
# medianmarechprebal30       11.000
# cnt_ma_rech90               2.000
# fr_ma_rech90                0.000
# sumamnt_ma_rech90        2317.000
# medianamnt_ma_rech90      773.000
# medianmarechprebal90       14.600
# cnt_da_rech30               0.000
# fr_da_rech30                0.000
# cnt_da_rech90               0.000
# fr_da_rech90                0.000
# cnt_loans30                 1.000
# amnt_loans30                6.000
# maxamnt_loans30             6.000
# ...

# %%
iqr_val=quantile3-quantile1
iqr_val
# Out:
# label                       0.000
# msisdn                 -93120.000
# aon                      -736.000
# daily_decr30            -7201.560
# daily_decr90            -7760.098
# rental30                -3076.520
# rental90                -3901.530
# last_rech_date_ma          -6.000
# last_rech_date_da           0.000
# last_rech_amt_ma        -1539.000
# cnt_ma_rech30              -4.000
# fr_ma_rech30               -6.000
# sumamnt_ma_rech30       -8470.000
# medianamnt_ma_rech30    -1154.000
# medianmarechprebal30      -72.000
# cnt_ma_rech90              -6.000
# fr_ma_rech90               -8.000
# sumamnt_ma_rech90      -13683.000
# medianamnt_ma_rech90    -1151.000
# medianmarechprebal90      -64.710
# cnt_da_rech30               0.000
# fr_da_rech30                0.000
# cnt_da_rech90               0.000
# fr_da_rech90                0.000
# cnt_loans30                -3.000
# amnt_loans30              -18.000
# maxamnt_loans30             0.000
# ...

# %%
lower_limit=quantile1-(1.5*iqr_val)
upper_limit=quantile3+(1.5*iqr_val)

# %%
lower_limit
# Out:
# label                        1.000
# msisdn                  279306.000
# aon                       2086.000
# daily_decr30             18046.340
# daily_decr90             19442.937
# rental30                  7971.720
# rental90                 10054.085
# last_rech_date_ma           16.000
# last_rech_date_da            0.000
# last_rech_amt_ma          4617.500
# cnt_ma_rech30               11.000
# fr_ma_rech30                15.000
# sumamnt_ma_rech30        22715.000
# medianamnt_ma_rech30      3655.000
# medianmarechprebal30       191.000
# cnt_ma_rech90               17.000
# fr_ma_rech90                20.000
# sumamnt_ma_rech90        36524.500
# medianamnt_ma_rech90      3650.500
# medianmarechprebal90       176.375
# cnt_da_rech30                0.000
# fr_da_rech30                 0.000
# cnt_da_rech90                0.000
# fr_da_rech90                 0.000
# cnt_loans30                  8.500
# amnt_loans30                51.000
# maxamnt_loans30              6.000
# ...

# %%
upper_limit
# Out:
# label                       1.000
# msisdn                 -93174.000
# aon                      -858.000
# daily_decr30           -10759.900
# daily_decr90           -11597.455
# rental30                -4334.360
# rental90                -5552.035
# last_rech_date_ma          -8.000
# last_rech_date_da           0.000
# last_rech_amt_ma        -1538.500
# cnt_ma_rech30              -5.000
# fr_ma_rech30               -9.000
# sumamnt_ma_rech30      -11165.000
# medianamnt_ma_rech30     -961.000
# medianmarechprebal30      -97.000
# cnt_ma_rech90              -7.000
# fr_ma_rech90              -12.000
# sumamnt_ma_rech90      -18207.500
# medianamnt_ma_rech90     -953.500
# medianmarechprebal90      -82.465
# cnt_da_rech30               0.000
# fr_da_rech30                0.000
# cnt_da_rech90               0.000
# fr_da_rech90                0.000
# cnt_loans30                -3.500
# amnt_loans30              -21.000
# maxamnt_loans30             6.000
# ...

# %%
x.skew()
# Out:
# msisdn                   0.000719
# aon                     10.392949
# daily_decr30             3.946230
# daily_decr90             4.252565
# rental30                 4.521929
# rental90                 4.437681
# last_rech_date_ma       14.790974
# last_rech_amt_ma         3.781149
# cnt_ma_rech30            3.283842
# fr_ma_rech30            14.772833
# sumamnt_ma_rech30        6.386787
# medianamnt_ma_rech30     3.512324
# medianmarechprebal30    14.779875
# cnt_ma_rech90            3.425254
# fr_ma_rech90             2.285423
# sumamnt_ma_rech90        4.897950
# medianamnt_ma_rech90     3.752706
# medianmarechprebal90    44.880503
# cnt_da_rech30           17.818364
# fr_da_rech30            14.776430
# cnt_da_rech90           27.267278
# fr_da_rech90            28.988083
# cnt_loans30              2.713421
# amnt_loans30             2.975719
# maxamnt_loans30         17.658052
# medianamnt_loans30       4.551043
# cnt_loans90             16.594408
# ...

# %% [markdown]
# Check Skewness and Try to reduce the skewness

# %%
sns.kdeplot(Micro_Loan_df['aon'])
# Out:
# <AxesSubplot:xlabel='aon', ylabel='Density'>

# %% [markdown]
# Right Skewed and it is positive skewness

# %%
quant =Micro_Loan_df['aon'].quantile(.99)

# %%
new = Micro_Loan_df['aon'][Micro_Loan_df['aon'] < quant]
sns.kdeplot(new)
# Out:
# <AxesSubplot:xlabel='aon', ylabel='Density'>

# %% [markdown]
# Removed the majority of skewness

# %%
sns.kdeplot(Micro_Loan_df['last_rech_date_ma'])
# Out:
# <AxesSubplot:xlabel='last_rech_date_ma', ylabel='Density'>

# %% [markdown]
# Right skewed ad its is postive skewness try to remove data from right

# %%
quant = Micro_Loan_df['last_rech_date_ma'].quantile(0.99)

# %%
new_1 = Micro_Loan_df['last_rech_date_ma'][Micro_Loan_df['last_rech_date_ma']<quant]
sns.kdeplot(new_1)
# Out:
# <AxesSubplot:xlabel='last_rech_date_ma', ylabel='Density'>

# %%
sns.kdeplot(Micro_Loan_df['medianmarechprebal90'])
# Out:
# <AxesSubplot:xlabel='medianmarechprebal90', ylabel='Density'>

# %% [markdown]
# higly right skewed

# %%
quant = df['medianmarechprebal90'].quantile(0.99)

# %%
new_2=Micro_Loan_df['medianmarechprebal90'][Micro_Loan_df['medianmarechprebal90']<quant]
sns.kdeplot(new_2)
# Out:
# <AxesSubplot:xlabel='medianmarechprebal90', ylabel='Density'>

# %%
quant1 =Micro_Loan_df['aon'].quantile(.99)
quant2 = Micro_Loan_df['last_rech_date_ma'].quantile(0.99)
quant3 = Micro_Loan_df['medianmarechprebal90'].quantile(0.99)

# %%
Micro_Loan_df.shape
# Out:
# (209593, 36)

# %%
Micro_Loan_df=Micro_Loan_df[Micro_Loan_df['aon']<quant1]
print(Micro_Loan_df.shape)
Micro_Loan_df=Micro_Loan_df[Micro_Loan_df['last_rech_date_ma']<quant2]
print(Micro_Loan_df.shape)
Micro_Loan_df=Micro_Loan_df[Micro_Loan_df['medianmarechprebal90']<quant3]
print(Micro_Loan_df.shape)
# Out:
# (207497, 36)
# (205399, 36)
# (203401, 36)

# %%
Micro_Loan_df.shape
# Out:
# (203401, 36)

# %%
Micro_Loan_df
# Out:
#         label  msisdn     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   40191   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1  142291   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   33594   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1  104157   241.0     21.228000     21.228000    159.42    159.42
# 4           1    6910   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...     ...           ...           ...       ...       ...
# 209588      1   42866   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  178248  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1   53995  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  111388  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  121263  1581.0   4489.362000   4534.820000    483.92    631.20
#
# ...

# %%
x=Micro_Loan_df.drop(['label','month','day','last_rech_date_da','medianamnt_loans90','medianamnt_loans30','last_rech_date_da','cnt_da_rech90','fr_da_rech90','cnt_da_rech30','fr_da_rech30'],axis=1); #month and day also in categorial form thats why eliminate
y=Micro_Loan_df['label']

# %% [markdown]
# Model Training
# Removing Outliers loosing a lot of data so i train data with model which are not sensitive to ouliers

# %%
x
# Out:
#         msisdn     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0        40191   272.0   3055.050000   3065.150000    220.13    260.13
# 1       142291   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2        33594   535.0   1398.000000   1398.000000    900.13    900.13
# 3       104157   241.0     21.228000     21.228000    159.42    159.42
# 4         6910   947.0    150.619333    150.619333   1098.90   1098.90
# ...        ...     ...           ...           ...       ...       ...
# 209588   42866   404.0    151.872333    151.872333   1089.19   1089.19
# 209589  178248  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590   53995  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591  111388  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592  121263  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  ...  \
# ...

# %%
y
# Out:
# 0         0
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 209588    1
# 209589    1
# 209590    1
# 209591    1
# 209592    1
# Name: label, Length: 203401, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
from sklearn.tree import DecisionTreeClassifier
maxAcc=0
maxRs=0
for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=i)
    DT=DecisionTreeClassifier()
    DT.fit(x_train,y_train)
    pred=DT.predict(x_test)
    accu=accuracy_score(y_test,pred)
    if accu>maxAcc:
        maxAcc=accu
        maxRs=1
print("Best accuracy -",maxAcc,'Best Random state = ',maxRs)
#Best accuracy - 0.8687037230159558 Best Random state =  1
# Out:
# Best accuracy - 0.8677502495418858 Best Random state =  1

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=1)

# %%
from sklearn.svm import LinearSVC

clf = LinearSVC(random_state=1, tol=1e-5)

clf.fit(x_train, y_train.ravel())
# Out:
# LinearSVC(random_state=1, tol=1e-05)

# %%
pred=clf.predict(x_test)
accu=accuracy_score(y_test,pred)
classification_score=classification_report(y_test,pred)

print('Accuracy Score :', accu)
print('Classification Score :', classification_score)
# Out:
# Accuracy Score : 0.7280216915215351
# Classification Score :               precision    recall  f1-score   support
#
#            0       0.26      0.64      0.37      8265
#            1       0.94      0.74      0.83     58858
#
#     accuracy                           0.73     67123
#    macro avg       0.60      0.69      0.60     67123
# weighted avg       0.85      0.73      0.77     67123

# %%
DTC=DecisionTreeClassifier()
DTC.fit(x_train,y_train)
pred=DTC.predict(x_test)
accu=accuracy_score(y_test,pred)
classification_score=classification_report(y_test,pred)
confusion_matrix = confusion_matrix(y_test,pred)
print('Accuracy Score :', accu)
print('Classification Score :', classification_score)
print('confusion Matrix :', confusion_matrix)
# Out:
# Accuracy Score : 0.8647855429584494
# Classification Score :               precision    recall  f1-score   support
#
#            0       0.45      0.49      0.47      8265
#            1       0.93      0.92      0.92     58858
#
#     accuracy                           0.86     67123
#    macro avg       0.69      0.70      0.70     67123
# weighted avg       0.87      0.86      0.87     67123
#
# confusion Matrix : [[ 4026  4239]
#  [ 4837 54021]]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

# %%
RF=RandomForestClassifier(n_estimators=100)
RF.fit(x_train,y_train)
pred=RF.predict(x_test)
accu=accuracy_score(y_test,pred)
classification_score=classification_report(y_test,pred)

print('Accuracy Score :', accu)
print('Classification Score :', classification_score)
# Out:
# Accuracy Score : 0.9139639169882157
# Classification Score :               precision    recall  f1-score   support
#
#            0       0.76      0.44      0.56      8265
#            1       0.93      0.98      0.95     58858
#
#     accuracy                           0.91     67123
#    macro avg       0.84      0.71      0.75     67123
# weighted avg       0.91      0.91      0.90     67123

# %%
AD=AdaBoostClassifier(n_estimators=100)
AD.fit(x_train,y_train)
pred=AD.predict(x_test)
accu=accuracy_score(y_test,pred)
classification_score=classification_report(y_test,pred)

print('Accuracy Score :', accu)
print('Classification Score :', classification_score)
# Out:
# Accuracy Score : 0.9057551062973943
# Classification Score :               precision    recall  f1-score   support
#
#            0       0.79      0.32      0.45      8265
#            1       0.91      0.99      0.95     58858
#
#     accuracy                           0.91     67123
#    macro avg       0.85      0.65      0.70     67123
# weighted avg       0.90      0.91      0.89     67123

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB

# %%
LG=LogisticRegression()
LG.fit(x_train,y_train)
pred=LG.predict(x_test)
accu=accuracy_score(y_test,pred)
classification_score=classification_report(y_test,pred)

print('Accuracy Score :', accu)
print('Classification Score :', classification_score)
# Out:
# Accuracy Score : 0.8771211060292299
# Classification Score :               precision    recall  f1-score   support
#
#            0       0.53      0.02      0.04      8265
#            1       0.88      1.00      0.93     58858
#
#     accuracy                           0.88     67123
#    macro avg       0.70      0.51      0.49     67123
# weighted avg       0.84      0.88      0.82     67123

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

from sklearn.metrics import roc_auc_score

# %%
y_pred_prob=LG.predict_proba(x_test)[:,1]

# %%
y_pred_prob
# Out:
# array([0.99958963, 0.99996611, 0.99994802, ..., 0.98251846, 0.87398129,
#        0.81820708])

# %%
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)

# %%
thresholds
# Out:
# array([2.00000000e+00, 1.00000000e+00, 1.00000000e+00, ...,
#        8.65195961e-02, 5.86677463e-02, 1.31248261e-04])

# %%
fpr
# Out:
# array([0.00000000e+00, 1.20992136e-04, 1.20992136e-04, ...,
#        9.99879008e-01, 1.00000000e+00, 1.00000000e+00])

# %%
tpr
# Out:
# array([0.        , 0.00108736, 0.00120629, ..., 0.99988107, 0.99988107,
#        1.        ])

# %%
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='Logistic Regression')
plt.xlabel('False Positive rate')
plt.ylabel('True Postive rate')
plt.title('Logistic Regression')
plt.show()

# %%
auc_score=roc_auc_score(y_test,LG.predict(x_test))

# %%
auc_score
# Out:
# 0.5093486004859954

# %% [markdown]
# Accuracy Score is not good

# %% [markdown]
# Checking Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
print('Decission Tree :',cross_val_score(DTC,x,y,cv=5).mean())
# Out:
# Decission Tree : 0.865035072748792

# %%
print('Random Forest :',cross_val_score(RF,x,y,cv=5).mean())
# Out:
# Random Forest : 0.9134665031863982

# %%
print('Adaboost Tree  :',cross_val_score(AD,x,y,cv=5).mean())
# Out:
# Adaboost Tree  : 0.9054724354008694

# %%
print('Logistic Regression: ',cross_val_score(LG,x,y,cv=5).mean())
# Out:
# Logistic Regression:  0.876519782294441

# %%
print('Support Vector :',cross_val_score(clf,x,y,cv=5).mean())
# Out:
# Support Vector : 0.7986683168176834

# %% [markdown]
# DTC is best model having least difference

# %% [markdown]
# HYPERPERAMETER TUNNING

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter ={'max_depth':np.arange(2,10),
           'criterion':['gini', 'entropy'],
           'splitter':['best','random']}

# %%
GCV=GridSearchCV(DecisionTreeClassifier(),parameter,cv=5)
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': array([2, 3, 4, 5, 6, 7, 8, 9]),
#                          'splitter': ['best', 'random']})

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 8, 'splitter': 'best'}

# %%
Final_model=DecisionTreeClassifier(criterion='gini',max_depth=8,splitter='best')
Final_model.fit(x_train,y_train)
pred=Final_model.predict(x_test)
accu=accuracy_score(y_test,pred)
print(accu*100)
# Out:
# 90.81536880056017

# %% [markdown]
# # Saving the Model

# %%
import joblib
joblib.dump(Final_model,'Final_model.pkl')
# Out:
# ['Final_model.pkl']
